# %% [markdown]
# <div style="text-align: center; background-color: skyblue; font-family: 'Times New Roman', serif; color: white; padding: 20px; font-size: 36px; font-weight: bold; border-radius: 15px; box-shadow: 0px 6px 15px rgba(0, 0, 0, 0.2); transition: all 0.3s ease;">
#     INTRODUCTION TO DATA SCIENCE<br>
#     @ FIT-HCMUS, VNU-HCM<br>
#     FINAL PROJECT 🏫
# </div>
# <style>
#     div:hover {
#         transform: scale(1.05);
#         box-shadow: 0px 10px 20px rgba(0, 0, 0, 0.3);
#     }
# </style>

# %% [markdown]
# <div style="text-align: center; background-color: #ADD8E6; font-family: 'Times New Roman', serif; color: white; padding: 20px; font-size: 30px; font-weight: bold; border-radius: 10px; box-shadow: 0px 6px 15px rgba(0, 0, 0, 0.2); transition: all 0.3s ease;">
#     THE ANALYSIS OF THE MOBILE PHONE MARKET AT MOBILE CITY STORE
# </div>
# <style>
#     div:hover {
#         transform: scale(1.05);
#         box-shadow: 0px 10px 20px rgba(0, 0, 0, 0.3);
#     }
# </style>

# %% [markdown]
# ---

# %% [markdown]
# <div style="text-align: center; background-color: #ADD8E6; font-family: 'Times New Roman', serif; color: white; padding: 25px; font-size: 20px; font-weight: bold; border-radius: 10px; box-shadow: 0px 6px 15px rgba(0, 0, 0, 0.2); transition: all 0.3s ease;">
#     DATA EXPLORATION
# </div>
# <style>
#     div:hover {
#         opacity: 0.8;
#     }
# </style>

# %% [markdown]
# **Người thực hiện**: Trương Tiến Anh
#
# **MSSV**: 22120017
#
# **Người thực hiện**: Lê Nguyễn Gia Bảo
#
# **MSSV**: 22120023
#
# **Người thực hiện**: Nguyễn Hữu Bền
#
# **MSSV**: 22120029
#
# **Người thực hiện**: Đoàn Minh Cường
#
# **MSSV**: 22120043

# %% [markdown]
# ---

# %% [markdown]
# # Thư viện

# %%
# Import các thư viện cần thiết
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import ast

# %% [markdown]
# # Sử dụng data đã được xử lý

# %%
# Đọc file csv
data = pd.read_csv('../data/processed_data.csv', index_col=0)

# Chuyển đổi object thành list
data["do_phan_giai_cam_truoc"] = data["do_phan_giai_cam_truoc"].apply(ast.literal_eval)
data["do_phan_giai_cam_sau"] = data["do_phan_giai_cam_sau"].apply(ast.literal_eval)

data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8662 entries, 0 to 8661
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ten                     8662 non-null   object
#  1   loai_dien_thoai         8662 non-null   object
#  2   thoi_gian_bao_hanh      8662 non-null   float64
#  3   danh_gia                8662 non-null   float64
#  4   so_luong_binh_luan      8662 non-null   int64
#  5   duong_dan               8662 non-null   object
#  6   mau_sac                 8376 non-null   object
#  7   gia_moi                 7148 non-null   float64
#  8   gia_cu                  5083 non-null   float64
#  9   he_dieu_hanh            8662 non-null   object
#  10  cpu                     8647 non-null   object
#  11  ram                     8646 non-null   float64
#  12  bo_nho_trong            8362 non-null   float64
#  13  dung_luong_pin          8462 non-null   float64
#  14  thiet_ke                8546 non-null   object
#  15  hang_dien_thoai         8662 non-null   object
#  16  kich_thuoc_man_hinh     8325 non-null   float64
#  17  tan_so_quet             6561 non-null   float64
#  18  do_sang_man_hinh        5183 non-null   float64
#  19  loai_man_hinh           8332 non-null   object
#  20  so_the_sim              8662 non-null   int64
#  21  loai_pin                6571 non-null   object
#  22  cong_suat_sac           8173 non-null   float64
#  23  do_phan_giai_cam_sau    8662 non-null   object
#  24  do_phan_giai_cam_truoc  8662 non-null   object
# dtypes: float64(11), int64(2), object(12)
# memory usage: 1.7+ MB
#                                         ten loai_dien_thoai  \
# 0  Điện thoại LG G7 ThinQ cũ (Mỹ, Hàn Quốc)              LG
# 1  Điện thoại LG G7 ThinQ cũ (Mỹ, Hàn Quốc)              LG
# 2  Điện thoại LG G7 ThinQ cũ (Mỹ, Hàn Quốc)              LG
# 3  Điện thoại LG G7 ThinQ cũ (Mỹ, Hàn Quốc)              LG
# 4  Điện thoại LG G7 ThinQ cũ (Mỹ, Hàn Quốc)              LG
#
#    thoi_gian_bao_hanh  danh_gia  so_luong_binh_luan  \
# 0                 6.0       5.0                1191
# 1                 6.0       5.0                1191
# 2                 6.0       5.0                1191
# 3                 6.0       5.0                1191
# 4                 6.0       5.0                1191
#
#                                 duong_dan mau_sac    gia_moi     gia_cu  \
# 0  https://mobilecity.vn/lg/lg-g7-cu.html     Xám  1750000.0  2950000.0
# 1  https://mobilecity.vn/lg/lg-g7-cu.html     Xám  2050000.0  2950000.0
# 2  https://mobilecity.vn/lg/lg-g7-cu.html   Trắng  1750000.0  2950000.0
# 3  https://mobilecity.vn/lg/lg-g7-cu.html   Trắng  2050000.0  2950000.0
# 4  https://mobilecity.vn/lg/lg-g7-cu.html    Xanh  1750000.0  2950000.0
#
#   he_dieu_hanh  ... hang_dien_thoai  kich_thuoc_man_hinh  tan_so_quet  \
# 0    Android 8  ...              LG                  6.1          NaN
# 1    Android 8  ...              LG                  6.1          NaN
# 2    Android 8  ...              LG                  6.1          NaN
# 3    Android 8  ...              LG                  6.1          NaN
# 4    Android 8  ...              LG                  6.1          NaN
#
#    do_sang_man_hinh loai_man_hinh so_the_sim  loai_pin  cong_suat_sac  \
# 0               NaN           LCD          2       NaN           18.0
# 1               NaN           LCD          2       NaN           18.0
# 2               NaN           LCD          2       NaN           18.0
# 3               NaN           LCD          2       NaN           18.0
# 4               NaN           LCD          2       NaN           18.0
#
#    do_phan_giai_cam_sau do_phan_giai_cam_truoc
# 0          [16.0, 16.0]                  [8.0]
# 1          [16.0, 16.0]                  [8.0]
# 2          [16.0, 16.0]                  [8.0]
# 3          [16.0, 16.0]                  [8.0]
# 4          [16.0, 16.0]                  [8.0]
#
# [5 rows x 25 columns]

# %% [markdown]
# # Câu hỏi: Mức giá giảm có ảnh hưởng đến lượt đánh giá và mức độ hài lòng của khách hàng không?

# %% [markdown]
# ## Mục đích

# %% [markdown]
# ## Tiền xử lý

# %%
df = data[["gia_cu", "gia_moi", "so_luong_binh_luan"]].copy().dropna()

# Tính toán mức giá giảm = Gía cũ - Gía mới
df['Mức giá giảm'] = df['gia_cu'] - df['gia_moi']
df['Có giảm giá'] = df['Mức giá giảm'] > 0

#Tính trung bình lượt đánh giá theo sản phẩm có giảm giá
mean_rate = df.groupby('Có giảm giá')['so_luong_binh_luan'].mean()
mean_rate
# Out:
# Có giảm giá
# False    455.638710
# True     245.232216
# Name: so_luong_binh_luan, dtype: float64

# %% [markdown]
# ## Trực quan hóa

# %%
# Vẽ biểu đồ phân tán: Mức giảm giá với Số lượt đánh giá
plt.scatter(df['Mức giá giảm'], df['so_luong_binh_luan'], alpha=0.7)
plt.title("Mức giảm giá vs Số lượt đánh giá")
plt.xlabel("Mức giảm giá (VNĐ)")
plt.ylabel("Số lượt đánh giá và hỏi đáp")
plt.grid(True)
plt.show()

#Hệ số tương quan
correlation = df['Mức giá giảm'].corr(df['so_luong_binh_luan'])
print(f'Hệ số tương quan: {correlation}')
# Out:
# Hệ số tương quan: -0.0630189080063586

# %% [markdown]
# ## Nhận xét

# %% [markdown]
# # Câu hỏi: Thời gian bảo hành có ảnh hưởng đến sự hài lòng của khách hàng không?

# %% [markdown]
# ## Mục đích

# %% [markdown]
# ## Tiền xử lý

# %%
df = data[["thoi_gian_bao_hanh", "danh_gia"]].copy().dropna()

# Tính trung bình đánh giá theo 'Thời gian bảo hành (tháng)'
mean_satisfaction = df.groupby('thoi_gian_bao_hanh')['danh_gia'].mean()
mean_satisfaction
# Out:
# thoi_gian_bao_hanh
# 0.0     4.985872
# 1.0     4.975000
# 6.0     4.975118
# 12.0    4.985815
# 15.0    5.000000
# 18.0    4.975660
# 24.0    5.000000
# 30.0    4.957143
# Name: danh_gia, dtype: float64

# %% [markdown]
# ## Trực quan hóa

# %%
plt.plot(mean_satisfaction.index, mean_satisfaction.values, marker='o')
plt.title('Thời gian bảo hành vs. Sự hài lòng')
plt.xlabel('Thời gian bảo hành (tháng)')
plt.ylabel('Điểm hài lòng trung bình')
plt.grid(True)
plt.show()

correlation = data['thoi_gian_bao_hanh'].corr(data['danh_gia'])
print(f'Hệ số tương quan: {correlation}')
# Out:
# Hệ số tương quan: 0.014617309719820304

# %% [markdown]
# ## Nhận xét

# %% [markdown]
# # Câu hỏi: Dòng điện thoại nào được quan tâm nhiều nhất từ trước đến nay dựa trên số lượt đánh giá và hỏi đáp? (Top 10)

# %% [markdown]
# ## Mục đích

# %% [markdown]
# ## Tiền xử lý

# %%
df = data[["hang_dien_thoai", "so_luong_binh_luan"]].copy().dropna()
df = df.groupby("hang_dien_thoai")["so_luong_binh_luan"].sum().sort_values(ascending=False).to_frame().reset_index().head(10)
df
# Out:
#   hang_dien_thoai  so_luong_binh_luan
# 0          Xiaomi              796959
# 1          Realme              201381
# 2          iPhone              123334
# 3         Samsung               91561
# 4            Vivo               89217
# 5              LG               23339
# 6          Vsmart               22779
# 7            Asus               22247
# 8         OnePlus               17683
# 9           Nubia               17575

# %% [markdown]
# ## Trực quan hóa

# %%
plt.figure(figsize=(10, 6))
plt.barh(df["hang_dien_thoai"], df["so_luong_binh_luan"], color='skyblue')
plt.xlabel('Số lượng đánh giá', fontsize=12)
plt.ylabel('Dòng điện thoại', fontsize=12)
plt.title('Số lượng đánh giá theo dòng điện thoại', fontsize=14)
plt.gca().invert_yaxis()  # Invert the y-axis for better visualization
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Nhận xét

# %% [markdown]
# # Câu hỏi: Ứng với mỗi dòng điện thoại thì những mẫu điện thoại nào được quan tâm nhiều nhất? (Top 3)

# %% [markdown]
# ## Mục đích

# %% [markdown]
# ## Tiền xử lý

# %%
df = data[["hang_dien_thoai", "so_luong_binh_luan"]].copy().dropna()
df = df.groupby("hang_dien_thoai")["so_luong_binh_luan"].sum().sort_values(ascending=False).to_frame().reset_index().head(10)
brands = df["hang_dien_thoai"].to_list()
df = data[["hang_dien_thoai", "ten", "so_luong_binh_luan"]].copy().drop_duplicates().dropna()
df = (
    df.reset_index()
    .sort_values(["hang_dien_thoai", "so_luong_binh_luan", "ten"], ascending=[False, False, False])
    .groupby("hang_dien_thoai")
    .head(3)
)
df = df[df["hang_dien_thoai"].isin(brands)][["hang_dien_thoai", "so_luong_binh_luan", "ten"]].reset_index(drop=True)
df["order"] = pd.Categorical(df["hang_dien_thoai"], categories=brands, ordered=True).codes + 1
df = df.sort_values("order").reset_index(drop=True).drop(columns="order")
df = df[["hang_dien_thoai", "ten", "so_luong_binh_luan"]]
df.columns = ["Dòng điện thoại", "Tên điện thoại", "Số lượng bình luận"]
df
# Out:
#    Dòng điện thoại                                     Tên điện thoại  \
# 0           Xiaomi         Điện thoại Xiaomi Redmi K20 Pro (Snap 855)
# 1           Xiaomi    Điện thoại Xiaomi Redmi Note 8 Pro (Helio G90T)
# 2           Xiaomi                        Điện thoại Xiaomi Redmi K20
# 3           Realme                           Điện thoại Realme X2 Pro
# 4           Realme                 Điện thoại Realme X (Camera Popup)
# 5           Realme                 Điện thoại Realme Q (Realme 5 Pro)
# 6           iPhone               Điện thoại iPhone XS cũ (Chính hãng)
# 7           iPhone  Điện thoại iPhone 7 Plus Lock Nhật, Mỹ (Dùng n...
# 8           iPhone               Điện thoại iPhone XR cũ (Chính hãng)
# 9          Samsung  Điện thoại Samsung Galaxy Note 9 cũ (128GB - 5...
# 10         Samsung  Điện thoại Samsung Galaxy A90 5G Cũ (Snapdrago...
# 11         Samsung  Điện thoại Samsung Galaxy S10 5G cũ (99,9%) (M...
# 12            Vivo                           Điện thoại Vivo iQOO Z1x
# 13            Vivo                       Điện thoại Vivo iQOO Neo 855
# 14            Vivo                           Điện thoại Vivo iQOO Neo
# 15              LG  Điện thoại LG V50S ThinQ 5G cũ (Snapdragon 855...
# 16              LG  Điện thoại LG G8 ThinQ Cũ (Snapdragon 855, màn...
# 17              LG           Điện thoại LG G7 ThinQ cũ (Mỹ, Hàn Quốc)
# 18          Vsmart                           Điện thoại Vsmart Live 4
# 19          Vsmart                            Điện thoại Vsmart Joy 4
# 20          Vsmart                Điện thoại Vsmart Live (Chính Hãng)
# 21            Asus      Điện thoại Asus ROG Phone 2 (Snapdragon 855+)
# 22            Asus    Điện thoại Asus ROG Phone 5 5G (Snapdragon 888)
# 23            Asus                Điện thoại Asus ROG Phone 3 Tencent
# 24         OnePlus                              Điện thoại OnePlus 8T
# 25         OnePlus                  Điện thoại OnePlus 7 Pro cũ (99%)
# 26         OnePlus                               Điện thoại OnePlus 8
# 27           Nubia  Điện thoại Nubia Red Magic 8 Pro 5G (Snapdrago...
# 28           Nubia       Điện thoại Nubia Red Magic 5G (Gaming Phone)
# 29           Nubia  Điện thoại Nubia Red Magic 7 (Snapdragon 8 Gen...
#
#     Số lượng bình luận
# 0                 5490
# 1                 4730
# 2                 3639
# 3                 2870
# 4                 2934
# 5                 4514
# 6                 1763
# 7                 1388
# 8                 1239
# 9                  805
# 10                1359
# 11                 801
# 12                1697
# 13                3873
# 14                1100
# 15                 806
# 16                1090
# 17                1191
# 18                 434
# 19                 466
# 20                1505
# 21                3508
# 22                 797
# 23                1022
# 24                 566
# 25                1481
# 26                 470
# 27                 309
# 28                 585
# 29                 325

# %% [markdown]
# ## Trực quan hóa

# %%
# Adjusting the row height to make the table rows narrower
fig, ax = plt.subplots(figsize=(22, 4))

# Hide axes
ax.axis('tight')
ax.axis('off')

# Create a table with adjusted row heights
table = ax.table(
    cellText=df.values,
    colLabels=df.columns,
    cellLoc='center',
    loc='center'
)

# Set font size and adjust row height
table.auto_set_font_size(False)
table.set_fontsize(10)
for key, cell in table.get_celld().items():
    cell.set_height(0.08)  # Adjust row height

plt.show()

# %% [markdown]
# ## Nhận xét

# %% [markdown]
# # Câu hỏi: Hãng điện thoại có ảnh hưởng đến giá cả không?

# %% [markdown]
# ## Mục đích

# %% [markdown]
# ## Tiền xử lý

# %%
df = data[["hang_dien_thoai", "gia_moi"]].copy().dropna()
df = df.groupby("hang_dien_thoai")["gia_moi"].mean().sort_values(ascending=False).to_frame().reset_index()
df
# Out:
#    hang_dien_thoai       gia_moi
# 0             Oppo  3.865000e+07
# 1              NIO  2.326567e+07
# 2           Google  2.047551e+07
# 3        Fairphone  1.835000e+07
# 4           iPhone  1.823960e+07
# 5             Asus  1.661104e+07
# 6            Honor  1.611550e+07
# 7              ZTE  1.519157e+07
# 8             Sony  1.400006e+07
# 9            Meizu  1.230574e+07
# 10           Nubia  1.226859e+07
# 11            OPPO  1.214949e+07
# 12         OnePlus  1.197702e+07
# 13        Motorola  1.164774e+07
# 14             Red  1.145000e+07
# 15            Vivo  1.062665e+07
# 16        MoonDrop  1.050000e+07
# 17         Samsung  1.046686e+07
# 18          Lenovo  1.007632e+07
# 19        Unihertz  9.950000e+06
# 20         Nothing  9.245882e+06
# 21       Smartisan  8.950000e+06
# 22            POCO  8.675000e+06
# 23          Huawei  8.010833e+06
# 24         Ulefone  7.766000e+06
# 25         Infinix  7.395556e+06
# 26          Xiaomi  7.235763e+06
# 27          Realme  6.197633e+06
# 28             BLU  6.150000e+06
# 29     Bkav Bphone  6.050000e+06
# 30       Blackview  5.650000e+06
# 31           Tecno  4.506500e+06
# 32         Meiigoo  4.450000e+06
# 33           Nokia  4.231818e+06
# 34           Thành  3.290000e+06
# 35           LeEco  3.012500e+06
# 36            itel  2.983333e+06
# 37          Vsmart  2.616182e+06
# 38          Gionee  2.600000e+06
# 39              LG  2.466129e+06
# 40            Bkav  2.410000e+06

# %% [markdown]
# ## Trực quan hóa

# %%
# Plotting the bar chart
plt.figure(figsize=(15, 6))
plt.bar(df["hang_dien_thoai"], df["gia_moi"], color='skyblue')
plt.title("Giá điện thoại trung bình theo dòng", fontsize=14)
plt.xlabel("Dòng điện thoại", fontsize=12)
plt.ylabel("Giá", fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Nhận xét
